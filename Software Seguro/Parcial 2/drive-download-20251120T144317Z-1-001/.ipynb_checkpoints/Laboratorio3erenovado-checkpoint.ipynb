# %% [markdown]
# # Laboratorio 3
#
# El modelo predice el Attack Type (tipo de ataque) basado en las columnas textuales: 'Scenario Description', 'Tools Used', 'Attack Steps ', 'Vulnerability' y 'Tags'. Estas se combinan en una sola característica de texto y se vectorizan usando TF-IDF.

# %% [markdown]
# ---
# #### Paso 1: Importar librerías y cargar el dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Cargar el dataset
df = pd.read_csv('Attack_Dataset.csv')

# Limpiar columna extra si existe
if 'Unnamed: 15' in df.columns:
    df = df.drop('Unnamed: 15', axis=1)

# Combinar columnas textuales en una sola para vectorización
df['combined_text'] = df['Scenario Description'].fillna('') + ' ' + \
                      df['Tools Used'].fillna('') + ' ' + \
                      df['Attack Steps '].fillna('') + ' ' + \
                      df['Vulnerability'].fillna('') + ' ' + \
                      df['Tags'].fillna('')

# Etiquetas (target)
y = df['Attack Type']

# Codificar etiquetas si son strings (Random Forest maneja strings, pero para consistencia usamos LabelEncoder)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %% [markdown]
# ---
# ### Paso 2: Preprocesamiento y vectorización

# %%
# Vectorización TF-IDF
vectorizer = TfidfVectorizer(max_features=5000, stop_words='english')  # Limitamos a 5000 features para eficiencia
X = vectorizer.fit_transform(df['combined_text'])

# Dividir en train/test
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %% [markdown]
# ---
# ### Paso 3: Crear y entrenar el modelo

# %%
# Crear el modelo Random Forest
model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)  # 100 árboles, usa todos los cores

# Entrenar
model.fit(X_train, y_train)

# Evaluar en test
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

labels = np.unique(np.concatenate([y_test, y_pred]))
target_names = label_encoder.inverse_transform(labels)
print(classification_report(y_test, y_pred, labels=labels, target_names=target_names))
# Out:
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")
# Accuracy: 0.2561018747789176
#                                                                                            precision    recall  f1-score   support
#
#                                                                   /proc Leak Exploitation       0.00      0.00      0.00         0
#                                                      4/6-digit App Lock PIN Code Guessing       0.00      0.00      0.00         1
#                                                         ABI Injection / Frontend Mismatch       0.00      0.00      0.00         0
#                                                                             ADS Technique       0.00      0.00      0.00         1
#                                 ADS payload in writable path → executed by privileged app       0.00      0.00      0.00         1
#                                                                 ADS-based Stealth Payload       0.00      0.00      0.00         1
#                                            AI Outputs Too Much Context Leading to Leakage       0.00      0.00      0.00         1
#                                           AI Voice Spoofing for Mobile Social Engineering       0.00      0.00      0.00         0
#                                                                                 API Abuse       0.50      0.20      0.29         5
#                                          API Abuse & Exfiltration via Telemetry Libraries       0.00      0.00      0.00         0
#                                                                    API Gateway Misrouting       0.00      0.00      0.00         0
#                                                                   API Introspection Abuse       0.00      0.00      0.00         0
#                            API Key Theft and Abuse for Transaction Injection & Data Leaks       0.00      0.00      0.00         1
#                                                                                API Misuse       0.00      0.00      0.00         0
#                                                         API Misuse / Function Call Hijack       0.00      0.00      0.00         1
#                                                                      API Misuse for Pivot       0.00      0.00      0.00         1
#                                API-Based Black-box Model Stealing Using Transfer Learning       0.00      0.00      0.00         1
#                                                                  API-Level Race Condition       0.00      0.00      0.00         1
#                                                                                 ARG Abuse       0.00      0.00      0.00         0
#                                                     ARP Cache Poisoning + Packet Sniffing       0.00      0.00      0.00         1
#                                                                   ARP Spoofing & Proxying       0.00      0.00      0.00         1
#                                                   ARP Spoofing for Default Gateway Hijack       0.00      0.00      0.00         0
#                                               ASO-Driven Malware Deployment in Play Store       0.00      0.00      0.00         0
#                                                 AWS Subdomain Takeover via Deleted Bucket       0.00      0.00      0.00         1
#                                                                Abandoned Library Takeover       0.00      0.00      0.00         1
#                                                                          Abnormal Sharing       0.00      0.00      0.00         1
#                                    Abuse capsule update to inject or tamper UEFI firmware       0.00      0.00      0.00         1
#                                                Abuse of Automation / Privilege Escalation       0.00      0.00      0.00         1
#                                          Abuse of Rate Limiting / Access-Control Controls       0.00      0.00      0.00         1
#                                                          Abuse of Split Tunneling in VPNs       0.00      0.00      0.00         1
#                                                   Abuse of Trivial File Transfer Protocol       0.00      0.00      0.00         1
#                                                              Abuse via Format Translation       0.00      0.00      0.00         0
#                                        Abusing Accessibility Services → OTP / 2FA Capture       0.00      0.00      0.00         1
#                                         Abusing Accessibility Services → Overlay Phishing       0.00      0.00      0.00         1
#                   Abusing Accessibility Services → UI Manipulation to Bypass Restrictions       0.00      0.00      0.00         0
#                                                       Abusing Email Auto-forwarding Rules       0.29      0.50      0.36         4
#                                                  Access Control Bypass via Function Calls       0.00      0.00      0.00         0
#                                                                     Access Control Misuse       0.00      0.00      0.00         1
#                                                               Access Token Replay / Theft       0.00      0.00      0.00         1
#                                                       Access or inject via /proc/[pid]/fd       0.00      0.00      0.00         1
#                                                                Accessibility-Based Attack       0.00      0.00      0.00         0
#                                                     Accessing Unlinked or Restricted URLs       0.00      0.00      0.00         0
#                                                             Accidental Credential Leakage       0.00      0.00      0.00         0
#                                                      Accidental Secret Leak in Debug Logs       0.00      0.00      0.00         0
#                                                                             Account Abuse       0.00      0.00      0.00         1
#                                                                Account Abuse / Logic Flaw       0.00      0.00      0.00         1
#                                                                          Account Takeover       0.00      0.00      0.00         1
#                                Account Takeover via Credential Stuffing or Password Spray       0.00      0.00      0.00         1
#                                                           Acoustic Relay Hum Side-Channel       0.00      0.00      0.00         1
#                                                              Acoustic Side-Channel Attack       0.00      0.00      0.00         1
#                                                  Acoustic Side-Channel via Fan/Coil Whine       0.00      0.00      0.00         1
#                                                            Acoustic/Hardware Side Channel       0.00      0.00      0.00         0
#                                                                          Action Tampering       0.00      0.00      0.00         1
#                                                  Active Jamming-Induced Protocol Fallback       0.00      0.00      0.00         0
#                                                           Active MITM + Payload Injection       0.00      0.00      0.00         0
#                                            Active Network MITM + HTTPS Downgrade Sniffing       0.00      0.00      0.00         0
#                                                                              Active Recon       0.00      0.00      0.00         1
#                                                              Active Test of Plugin Inputs       0.00      0.00      0.00         1
#                                                           Active/Passive Traffic Sniffing       0.00      0.00      0.00         1
#                                                        Adaptive Behavior via Falco Alerts       0.00      0.00      0.00         0
#                                                                          Adaptive Jamming       0.00      0.00      0.00         1
#                                                                 Advanced WEP Key Recovery       0.00      0.00      0.00         1
#                                                 Adversarial Bypass of Fairness Objectives       0.00      0.00      0.00         1
#                                             Adversarial Data Exploitation via Overfitting       0.00      0.00      0.00         1
#                                                                       Adversarial Evasion       0.00      0.00      0.00         1
#                                                           Adversarial Example (White-box)       1.00      1.00      1.00         1
#                                                      Adversarial Prompt Example Injection       0.00      0.00      0.00         0
#                                                              Adversarial Prompt Injection       0.00      0.00      0.00         1
#                                                       Adversarial Semantics across Models       0.00      0.00      0.00         0
#                                                                    Adversarial Subversion       0.00      0.00      0.00         0
#                                                                       Agent Loop Takeover       0.00      0.00      0.00         1
#                                                     Agent Planning Passes Sensitive Input       0.00      0.00      0.00         0
#                                                          Agent Requests Internal Services       0.00      0.00      0.00         1
#                                                 Agent accepts fake roles via input prompt       0.00      0.00      0.00         1
#                                                Agent follows OAuth flow to malicious site       0.00      0.00      0.00         0
#                                   Agent includes API keys, tokens, or passwords in source       0.00      0.00      0.00         0
#                                            Agent keeps session alive via artificial pings       0.00      0.00      0.00         0
#                                       Agent loops login requests and overloads the system       0.00      0.00      0.00         1
#                                                    Agent uses vulnerable requests package       0.00      0.00      0.00         1
#                                                Agent-chain reuse leaks data between users       0.00      0.00      0.00         1
#                                       Agents forward tokens to unintended agent instances       0.00      0.00      0.00         1
#                                                            Aggregate Membership Inference       0.00      0.00      0.00         1
#                                          Aggregation Reconstruction from Gradient Updates       0.00      0.00      0.00         1
#                                                                             Alert Fatigue       0.00      0.00      0.00         1
#                                                                             Alert Overlap       0.00      0.00      0.00         1
#                                                         Alternate Data Stream (ADS) Abuse       1.00      1.00      1.00         1
#                                                                 Alternate Input Same Hash       0.00      0.00      0.00         0
#                                                        Amplification of Malicious Updates       0.00      0.00      0.00         1
#                                          Amplification-Based DDoS Using DNS “ANY” Queries       0.00      0.00      0.00         1
#                                                                      Analog Noise Exploit       0.00      0.00      0.00         1
#                                                            Analog Wireless Signal Capture       0.00      0.00      0.00         0
#                                                                         Anomalous Sign-In       0.00      0.00      0.00         1
#                                                                      Anti-Sandbox Evasion       0.00      0.00      0.00         0
#                                                                           Anti-VM Evasion       1.00      0.67      0.80         3
#                                                                       App Container Abuse       0.00      0.00      0.00         1
#                                                                          App Exploitation       0.50      0.50      0.50         2
#                                     App Hijack and Privilege Escalation via Desktop Entry       0.00      0.00      0.00         1
#                  App creates temporary file insecurely, attacker replaces it with symlink       0.00      0.00      0.00         0
#                                                         App image poisoning during update       0.00      0.00      0.00         1
#                                                                       Application Exploit       0.00      0.00      0.00         1
#                                                                        Application Hijack       0.00      0.00      0.00         1
#                                                    Arbitrary Code Execution via Code Tool       0.00      0.00      0.00         0
#                                          Arbitrary Code Execution via LLM Code Suggestion       0.00      0.00      0.00         1
#                                                       Arbitrary Code Execution via import       0.00      0.00      0.00         1
#                                                            Arbitrary File Overwrite / RCE       0.00      0.00      0.00         1
#                                              Arbitrary File Write via Parameter Injection       0.00      0.00      0.00         1
#                                              Arbitrary File Write via Upload Path Control       0.00      0.00      0.00         0
#                                                                      Archive With Dropper       0.00      0.00      0.00         0
#                                               Argument Logging Leak via API Gateway/Proxy       0.00      0.00      0.00         1
#                                                       Argument logging without formatting       0.00      0.00      0.00         1
#                                                                    Argument-Based Fuzzing       0.00      0.00      0.00         0
#                                                                     Artifact Manipulation       0.00      0.00      0.00         1
#                                               Artificial Gas Savings via Storage Clearing       0.00      0.00      0.00         1
#                                        Artificial Memory Injection to Influence Responses       0.00      0.00      0.00         0
#                                                  Attack on RSA + Symmetric Hybrid Schemes       0.00      0.00      0.00         1
#                                                            Attacker-Controlled RNG Inputs       0.00      0.00      0.00         0
#                                                                        Attribution Attack       0.00      0.00      0.00         0
#                                                                Attribution Bias Detection       0.00      0.00      0.00         1
#                                                                          Attribution Trap       0.00      0.00      0.00         1
#                                                                        Auction Logic Bugs       0.00      0.00      0.00         1
#                                                            Audio Playback Trigger Exploit       0.00      0.00      0.00         0
#                                                                        Audio Surveillance       0.00      0.00      0.00         0
#                                                      Audio-based Adversarial Perturbation       0.00      0.00      0.00         0
#                                                               AudioContext Fingerprinting       0.00      0.00      0.00         1
#                                                              Audit/Explainability Evasion       0.00      0.00      0.00         0
#                                                         Auth Bypass via Decryption Oracle       0.00      0.00      0.00         0
#                                                       Auth Bypass via Insecure Logic Flow       0.00      0.00      0.00         1
#                                                                     Authentication Bypass       0.00      0.00      0.00         1
#                                              Authentication Bypass / Privilege Escalation       0.00      0.00      0.00         0
#                                                              Authentication Bypass in VNC       0.00      0.00      0.00         1
#                                                      Authentication Bypass via Broken MFA       0.00      0.00      0.00         1
#                                                   Authentication Bypass via Serialization       0.00      0.00      0.00         0
#                                                  Authentication Bypass via Weak Passwords       0.00      0.00      0.00         0
#                                                   Authentication Misconfiguration Exploit       0.00      0.00      0.00         1
#                                                          Authority Impersonation Phishing       0.00      0.00      0.00         1
#                                                                           Authority Phish       0.00      0.00      0.00         1
#                                                           Authorization & Input Tampering       0.00      0.00      0.00         0
#                                                   Authorization Bypass via Role Confusion       0.00      0.00      0.00         0
#                                             Authorization Bypass via msg.sender Confusion       0.00      0.00      0.00         1
#                                                                   Auto Screenshot Capture       1.00      1.00      1.00         1
#                                                                  Auto-Execute NFC Payload       0.00      0.00      0.00         1
#                                                                  AutoPlay-Based Execution       0.00      0.00      0.00         1
#                                                              Autocomplete Data Extraction       0.00      0.00      0.00         0
#                                                                      Automation & Scaling       0.00      0.00      0.00         2
#                                                                        Automation Exploit       0.00      0.00      0.00         1
#                                                      BGP Hijack Targeting Mail Server IPs       0.00      0.00      0.00         0
#                                                        BGP Instability via Route Flapping       0.00      0.00      0.00         1
#                                                                         BGP Prefix Hijack       0.00      0.00      0.00         1
#                                                             BGP Spoofed Message Injection       0.00      0.00      0.00         0
#                                              BGP-based Interception of Blockchain Traffic       0.00      0.00      0.00         0
#                                                                               BIOS Bypass       0.00      0.00      0.00         0
#                                                                            BIOS Tampering       0.00      0.00      0.00         1
#                                                                       BLE Beacon Flooding       0.00      0.00      0.00         1
#                                                                                   BLE DoS       0.00      0.00      0.00         1
#                                                                             BLE Injection       0.00      0.00      0.00         1
#                                                                      BLE Injection Attack       0.14      1.00      0.25         2
# ...
#                                                                  Wireless Logic Injection       0.00      0.00      0.00         1
#                                                                 Wireless Malware Delivery       0.00      0.00      0.00         1
#                                                                  Wireless Noise Injection       0.00      0.00      0.00         1
#                                                            Wireless Physical Fault Vector       0.00      0.00      0.00         1
#                                                                    Wireless Power Exploit       0.00      0.00      0.00         1
#                                                                Wireless Printer Hijacking       0.40      1.00      0.57         4
#                                                                   Wireless Protocol Abuse       0.00      0.00      0.00         1
#                                                                Wireless Protocol Spoofing       0.00      0.00      0.00         1
#                                                                        Wireless RF Replay       0.00      0.00      0.00         1
#                                                                            Wireless Recon       0.00      0.00      0.00         2
#                                                                    Wireless Replay Attack       0.00      0.00      0.00         1
#                                                                 Wireless Session Loop DoS       0.00      0.00      0.00         1
#                                                                     Wireless Signal Abuse       0.00      0.00      0.00         1
#                                                                   Wireless Slice Spoofing       0.00      0.00      0.00         1
#                                                                Wireless Stack Duplication       0.00      0.00      0.00         1
#                                                              Wireless Supply Chain Attack       0.00      0.00      0.00         1
#                                                              Wireless Timing Manipulation       0.00      0.00      0.00         1
#                                                                      Wireless Trust Abuse       0.00      0.00      0.00         1
#                                                         Wireless – Bluetooth Interference       0.00      0.00      0.00         1
#                                                            Wireless – Collision Injection       0.00      0.00      0.00         0
#                                                         Wireless – Fault Injection via RF       0.00      0.00      0.00         1
#                                                                Wireless – RF Interference       0.00      0.00      0.00         1
#                                                                     Wireless – RF Jamming       0.00      0.00      0.00         1
#                                                                Wireless – RF Relay Attack       0.00      0.00      0.00         1
#                                                           Wireless – Signal Strength Leak       0.00      0.00      0.00         1
#                                                    Wireless – Wi-Fi Protocol Exploitation       0.00      0.00      0.00         0
#                                                            Wireless – Zigbee Interception       0.00      0.00      0.00         1
#                                                               Workflow Template Hardening       0.00      0.00      0.00         1
#                                                                                       XSS       0.44      1.00      0.62         4
#                                                               XSS/Injection Vulnerability       0.00      0.00      0.00         1
#                                                                      YAML Comment Payload       0.00      0.00      0.00         1
#                                                                   Z-Wave Downgrade Attack       0.86      1.00      0.92         6
#                                                       Zero-day Exploit Delivery via Email       0.75      1.00      0.86         3
#                                                                    Zigbee Beacon Flooding       0.00      0.00      0.00         1
#                                                  Zigbee DoS on QKD Environmental Controls       0.00      0.00      0.00         1
#                                                       Zigbee Firmware Update Manipulation       0.00      0.00      0.00         1
#                                       Zigbee Hub Downgrade with Fake Capability Broadcast       0.00      0.00      0.00         1
#                                                                       Zigbee IV Collision       0.00      0.00      0.00         1
#                                                                     Zigbee Key Extraction       0.45      0.83      0.59         6
#                                                                  Zigbee Mesh Manipulation       0.00      0.00      0.00         1
#                                                                 Zigbee Replay & Injection       0.41      1.00      0.58         7
#                                                            Zigbee Wireless Replay Exploit       0.00      0.00      0.00         1
#                                                                              Zoom Exploit       0.00      0.00      0.00         1
#                                                                     document.domain Abuse       0.00      0.00      0.00         1
#                                                                              gdb, fuzzers       0.00      0.00      0.00         0
#                                                                     glibc, malloc exploit       0.00      0.00      0.00         1
#                                                                     iframe SOP Relaxation       0.00      0.00      0.00         1
#                                                                            kubectl Misuse       0.00      0.00      0.00         0
#                                                             macOS Disk Encryption Imaging       0.00      0.00      0.00         1
#                                                                             macOS Imaging       0.00      0.00      0.00         1
#                                                       mmap or shm leaks between processes       0.00      0.00      0.00         1
#                                                                     msbuild Payload Abuse       0.00      0.00      0.00         1
#                                                                        tmpfs Secrets Leak       0.00      0.00      0.00         0
#                                                                  vtable / IO Pointer Leak       0.00      0.00      0.00         1
#                                                                       window.opener Abuse       1.00      0.50      0.67         2
#                                                                window.opener Exploitation       0.00      0.00      0.00         0
#
#                                                                                  accuracy                           0.26      2827
#                                                                                 macro avg       0.05      0.07      0.05      2827
#                                                                              weighted avg       0.18      0.26      0.19      2827
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\elkin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ---
# ### Paso 4: Cómo utilizar el modelo para predicciones <br>
# Para hacer predicciones con valores propios o aleatorios:
# - **Valores propios:** Proporciona un diccionario con las claves: 'Scenario Description', 'Tools Used', 'Attack Steps ', 'Vulnerability', 'Tags'. Cada uno es un string.
# - **Valores aleatorios:** Selecciona una fila aleatoria del dataset y predice sobre ella (para simular).

# %%
def predict_attack_type(new_data, is_dict=True):
    """
    Predice el Attack Type dado un diccionario o una fila aleatoria.
    
    - Si is_dict=True: new_data es un dict con claves: 'Scenario Description', 'Tools Used', 
      'Attack Steps ', 'Vulnerability', 'Tags'.
    - Si is_dict=False: Selecciona una fila aleatoria del dataset.
    """
    if not is_dict:
        # Aleatorio: seleccionar fila random
        random_row = df.sample(1)
        combined = random_row['combined_text'].values[0]
        true_label = random_row['Attack Type'].values[0]
        print(f"Usando fila aleatoria (True Attack Type: {true_label})")
    else:
        # Propios: combinar textos
        combined = new_data.get('Scenario Description', '') + ' ' + \
                   new_data.get('Tools Used', '') + ' ' + \
                   new_data.get('Attack Steps ', '') + ' ' + \
                   new_data.get('Vulnerability', '') + ' ' + \
                   new_data.get('Tags', '')
    
    # Vectorizar
    new_vector = vectorizer.transform([combined])
    
    # Predecir
    pred_encoded = model.predict(new_vector)
    pred_label = label_encoder.inverse_transform(pred_encoded)[0]
    
    return pred_label

# Ejemplo con valores propios
custom_data = {
    'Scenario Description': 'A login form fails to validate input',
    'Tools Used': 'Burp Suite, SQLMap',
    'Attack Steps ': 'Enter payload OR 1=1',
    'Vulnerability': 'Unsanitized input',
    'Tags': 'SQLi, Web Security'
}
print("Predicción propia:", predict_attack_type(custom_data))

# Ejemplo aleatorio
print("Predicción aleatoria:", predict_attack_type(None, is_dict=False))
# Out:
# Predicción propia: SQL Injection / Command Injection
# Usando fila aleatoria (True Attack Type: Remote Code Execution)
# Predicción aleatoria: Remote Code Execution
